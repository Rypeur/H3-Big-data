# %%
import pandas as pd 
import numpy as np 
from sklearn import linear_model 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sb

pd.set_option('display.max_columns', None)

# %%
df_price = pd.read_csv('price_availability.csv', sep=";")
df_listing = pd.read_csv('listings_final.csv',sep=";")

# %%
df_price
# Out:
#          listing_id         day                       created  available  \
# 0           9810829  2018-12-08  2018-09-27 06:14:10.000+0000       True
# 1           9810829  2018-12-08  2018-09-26 19:34:02.000+0000       True
# 2          20897010  2018-12-09  2018-09-27 10:38:57.000+0000       True
# 3          20897010  2018-12-09  2018-09-27 06:10:27.000+0000       True
# 4          20897010  2018-12-09  2018-09-26 19:30:25.000+0000       True
# ...             ...         ...                           ...        ...
# 4748691    23608395  2018-09-06  2018-09-27 06:05:42.000+0000      False
# 4748692    23608395  2018-09-06  2018-09-26 19:31:32.000+0000      False
# 4748693     1447132  2018-12-27  2018-09-27 10:46:16.000+0000      False
# 4748694     1447132  2018-12-27  2018-09-27 06:07:36.000+0000      False
# 4748695     1447132  2018-12-27  2018-09-26 19:37:40.000+0000      False
#
#         local_currency  local_price  min_nights
# ...

# %%
df_listing
# Out:
#      Unnamed: 0  listing_id                                      name  \
# 0             0    28581061                           La maison Clery
# 1             1      661961       studio PARIS PLACE EDITH PIAF 75020
# 2             2     1261705  chambre privée à louer @ paris oberkampf
# 3             3     1318834            Appartement au coeur du Marais
# 4             4     1677091                       Lovely & Quiet flat
# ..          ...         ...                                       ...
# 995         995    28335197          Studio cosy Jardin du Luxembourg
# 996         996    28583013    Charmant  30m2 - Faubourg Saint Martin
# 997         997    28628316       Cosy flat in the marais - Best area
# 998         998    28792796         Appartement 3 chambres madeleine.
# 999         999    28682896                          Village Jourdain
#
#              type   city                    neighborhood   latitude  \
# ...

# %%
df_price = df_price.groupby('listing_id').mean()
df_price
# Out:
#             available  local_price  min_nights
# listing_id
# 5396         0.011494   102.363985    2.000000
# 7397         0.168297   110.107632   11.000000
# 9342         0.309198   396.863014    2.784736
# 10010        0.254593   136.154856    4.955381
# 10270        0.511688   105.779221    4.937662
# ...               ...          ...         ...
# 28836096     0.082707   321.428571    1.022556
# 28838519     0.083333    54.483333    5.000000
# 28840013     0.743083   112.122530    2.000000
# 28846494     0.225564   168.037594    4.000000
# 28851976     0.812030   128.000000    2.000000
#
# [11749 rows x 3 columns]

# %%
df = pd.merge(df_price, df_listing, on=['listing_id'])

# %%
df
# Out:
#      listing_id  available  local_price  min_nights  Unnamed: 0  \
# 0         56093   0.000000   170.000000    4.000000          12
# 1         57207   0.482940    49.952756    2.000000          13
# 2        114543   0.140260   107.374026    3.716883          19
# 3        149534   0.554974   169.000000    3.000000           9
# 4        164255   0.100580    75.876209    3.841393          28
# ..          ...        ...          ...         ...         ...
# 994    28684174   0.785156   725.175781    1.046875         662
# 995    28709644   0.954286   475.000000    6.000000         745
# 996    28751412   0.521053   117.000000    1.000000          88
# 997    28774896   0.840506   156.397468    1.000000         159
# 998    28792796   0.639098    49.184211    5.000000         998
#
#                                                   name          type   city  \
# 0                          Beau duplex dans le Marais    entire_home  Paris
# ...

# %%
df.describe()
# Out:
#          listing_id   available  local_price  min_nights  Unnamed: 0  \
# count  9.990000e+02  999.000000   999.000000  999.000000  999.000000
# mean   1.543276e+07    0.330071   189.304613    7.441345  499.410410
# std    9.305853e+06    0.272364   184.425492   21.041276  288.950197
# min    5.609300e+04    0.000000    17.863724    1.000000    0.000000
# 25%    6.341818e+06    0.075917    76.525248    2.000000  249.500000
# 50%    1.727835e+07    0.286842   144.000000    3.000000  499.000000
# 75%    2.378911e+07    0.545217   230.372596    4.000000  749.500000
# max    2.879280e+07    1.000000  1780.590674  310.000000  999.000000
#
#          latitude   longitude  person_capacity        beds    bedrooms  \
# count  999.000000  999.000000       999.000000  999.000000  999.000000
# mean    48.864251    2.345202         3.669670    2.058058    1.326326
# std      0.009824    0.031837         2.190568    1.500378    0.998806
# ...

# %%
X = np.array([df.person_capacity, df.bedrooms, df.bathrooms])
y = np.array(df.local_price)

X.shape
# Out:
# (3, 999)

# %%
y.shape
# Out:
# (999,)

# %%
X = X.reshape((999,3))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train.shape
# Out:
# (699, 3)

# %%
y_train.shape
# Out:
# (699,)

# %%
X_test.shape
# Out:
# (300, 3)

# %%
y_test.shape
# Out:
# (300,)

# %%
reg = LinearRegression().fit(X_train,y_train)
reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("Coefficients beta_j :\n{}\nCoefficients INTERCEPT beta_0 :\n{}".format(reg.coef_,reg.intercept_))
# Out:
# Coefficients beta_j :
# [ 0.05105275 -2.10531958 -4.05737923]
# Coefficients INTERCEPT beta_0 :
# 197.28226296650124

# %%
reg1 = reg.fit(X_train,y_train)
y_predict = reg.predict(X_test)
y_predict.size
# Out:
# 300

# %%
print("Mean squared error: {}\nR2 : {}".format(mean_squared_error(y_test,y_predict),r2_score(y_test,y_predict)))
# Out:
# Mean squared error: 35046.99302862562
# R2 : -0.010380011409886869
